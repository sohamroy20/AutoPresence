# %%
pip install caer --user
# Out:
# Collecting caer
#   Using cached https://files.pythonhosted.org/packages/85/9c/6c960df569c032f4c302c099cd3e0e38b135df21e787365e891dd732904d/caer-1.9.8-py3-none-any.whl
# Collecting opencv-contrib-python (from caer)
#   Using cached https://files.pythonhosted.org/packages/1b/28/db15a674d473959efbed4253471ae27f9e68dcb59f87e5a6ac163df4a027/opencv_contrib_python-4.5.1.48-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: mypy in d:\anaconda\lib\site-packages (from caer) (0.800)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from caer) (3.7.4.3)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from caer) (1.16.4)
# Requirement already satisfied: mypy-extensions<0.5.0,>=0.4.3 in d:\anaconda\lib\site-packages (from mypy->caer) (0.4.3)
# Requirement already satisfied: typed-ast<1.5.0,>=1.4.0 in d:\anaconda\lib\site-packages (from mypy->caer) (1.4.2)
# Installing collected packages: opencv-contrib-python, caer
# Successfully installed caer-1.9.8 opencv-contrib-python-4.5.1.48
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install canaro --user
# Out:
# Collecting canaro
#   Using cached https://files.pythonhosted.org/packages/25/5f/6e91dff59341333c780bd503590fccfa5482e16af66c16b965d8042522a6/canaro-1.1.0-py3-none-any.whl
# Requirement already satisfied: tensorflow in d:\anaconda\lib\site-packages (from canaro) (2.3.1)
# Requirement already satisfied: caer in c:\users\vadiraj rao\appdata\roaming\python\python37\site-packages (from canaro) (1.9.8)
# Requirement already satisfied: astunparse==1.6.3 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (1.6.3)
# Requirement already satisfied: absl-py>=0.7.0 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (0.11.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (1.16.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (3.3.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (2.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.8 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (0.2.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (0.33.4)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (1.12.0)
# Requirement already satisfied: gast==0.3.3 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (2.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (1.34.0)
# Requirement already satisfied: protobuf>=3.9.2 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (3.14.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.1 in d:\anaconda\lib\site-packages (from tensorflow->canaro) (1.11.2)
# Requirement already satisfied: mypy in d:\anaconda\lib\site-packages (from caer->canaro) (0.800)
# Requirement already satisfied: opencv-contrib-python in c:\users\vadiraj rao\appdata\roaming\python\python37\site-packages (from caer->canaro) (4.5.1.48)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from caer->canaro) (3.7.4.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in d:\anaconda\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow->canaro) (1.23.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow->canaro) (3.3.3)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\anaconda\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow->canaro) (0.15.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\anaconda\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow->canaro) (1.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\anaconda\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow->canaro) (0.4.2)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow->canaro) (2.22.0)
# Requirement already satisfied: setuptools>=41.0.0 in d:\anaconda\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow->canaro) (41.0.1)
# Requirement already satisfied: typed-ast<1.5.0,>=1.4.0 in d:\anaconda\lib\site-packages (from mypy->caer->canaro) (1.4.2)
# Requirement already satisfied: mypy-extensions<0.5.0,>=0.4.3 in d:\anaconda\lib\site-packages (from mypy->caer->canaro) (0.4.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->canaro) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->canaro) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in d:\anaconda\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->canaro) (4.6)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in d:\anaconda\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow->canaro) (0.17)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow->canaro) (1.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->canaro) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->canaro) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->canaro) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->canaro) (2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->canaro) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow->canaro) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow->canaro) (3.1.0)
# Installing collected packages: canaro
# Successfully installed canaro-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2 as cv
import numpy as np
import caer
import canaro
import gc
import sklearn.model_selection as skm

# %%
people = ['Mridul','Sarthak','Vadiraj','Soham']
channels = 1
char_path = r'D:\Face Recognition'

# %%
train = caer.preprocess_from_dir(char_path, people,channels=channels,IMG_SIZE=(200,200),isShuffle=True)

len(train)
# Out:
# [INFO] Could not find a file to load from. Generating the training data
# ----------------------------------------------
# 1 - Mridul
# 2 - Mridul
# 3 - Mridul
# 4 - Mridul
# 5 - Mridul
# 6 - Mridul
# 7 - Mridul
# 8 - Mridul
# 9 - Mridul
# 10 - Mridul
# 11 - Mridul
# 12 - Mridul
# 13 - Mridul
# 14 - Mridul
# 15 - Mridul
# 16 - Mridul
# 17 - Mridul
# 18 - Mridul
# 19 - Mridul
# 20 - Mridul
# 21 - Mridul
# 22 - Mridul
# 23 - Mridul
# 24 - Mridul
# 25 - Mridul
# 26 - Mridul
# 27 - Mridul
# 28 - Mridul
# 29 - Mridul
# 30 - Mridul
# 31 - Mridul
# 32 - Mridul
# 33 - Mridul
# 34 - Mridul
# 35 - Mridul
# 36 - Mridul
# 37 - Mridul
# 38 - Mridul
# 39 - Mridul
# 40 - Mridul
# 41 - Mridul
# 42 - Mridul
# 43 - Mridul
# 44 - Mridul
# 45 - Mridul
# 46 - Mridul
# 47 - Mridul
# 48 - Mridul
# 49 - Mridul
# 50 - Mridul
# 51 - Mridul
# 52 - Mridul
# 53 - Mridul
# 54 - Mridul
# 55 - Mridul
# 56 - Mridul
# 57 - Mridul
# 58 - Mridul
# 59 - Mridul
# 60 - Mridul
# 61 - Mridul
# 62 - Mridul
# 63 - Mridul
# 64 - Mridul
# 65 - Mridul
# 66 - Mridul
# 67 - Mridul
# 68 - Mridul
# 69 - Mridul
# 70 - Mridul
# 71 - Mridul
# 72 - Mridul
# 73 - Mridul
# 74 - Mridul
# 75 - Mridul
# 76 - Mridul
# 77 - Mridul
# 78 - Mridul
# 79 - Mridul
# 80 - Mridul
# 81 - Mridul
# 82 - Mridul
# 83 - Mridul
# 84 - Mridul
# 85 - Mridul
# 86 - Mridul
# 87 - Mridul
# 88 - Mridul
# 89 - Mridul
# 90 - Mridul
# 91 - Mridul
# 92 - Mridul
# 93 - Mridul
# 78 - Soham
# 79 - Soham
# 80 - Soham
# 81 - Soham
# 82 - Soham
# 83 - Soham
# 84 - Soham
# 85 - Soham
# 86 - Soham
# 87 - Soham
# 88 - Soham
# 89 - Soham
# 90 - Soham
# 91 - Soham
# 92 - Soham
# 93 - Soham
# 94 - Soham
# 95 - Soham
# 96 - Soham
# 97 - Soham
# 98 - Soham
# 99 - Soham
# 100 - Soham
# ----------------------------------------------
# [INFO] 400 files preprocessed! Took 0m 6s
# 400

# %%
featureSet , labels = caer.sep_train(train,IMG_SIZE=(200,200))

from tensorflow.keras.utils import to_categorical
featureSet = caer.normalize(featureSet)
labels = to_categorical(labels, len(people))

split_data = skm.train_test_split(featureSet, labels, test_size=.2)
x_train, x_val, y_train, y_val = (np.array(item) for item in split_data)

# %%
del train
del featureSet
del labels
gc.collect()
# Out:
# 50

# %%
BATCH_SIZE = 16
EPOCHS=3

datagen = canaro.generators.imageDataGenerator()
train_gen = datagen.flow(x_train, y_train, batch_size=BATCH_SIZE)

model = canaro.models.createSimpsonsModel(IMG_SIZE=(200,200), channels=channels, output_dim=len(people),
                                          loss='binary_crossentropy', decay=1e-6, learning_rate=0.001, momentum=0.9, nesterov=True)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 200, 200, 32)      320
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 198, 198, 32)      9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 99, 99, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 99, 99, 64)        18496
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 97, 97, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 48, 48, 256)       147712
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 46, 46, 256)       590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 23, 23, 256)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 23, 23, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 135424)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 135424)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              138675200
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 139,482,084
# Trainable params: 139,482,084
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
callbacks_list = [LearningRateScheduler(canaro.lr_schedule)]

# %%
training = model.fit(train_gen,
                    steps_per_epoch=len(x_train)//BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(x_val,y_val),
                    validation_steps=len(y_val)//BATCH_SIZE,
                    callbacks = callbacks_list)
# Out:
# Epoch 1/3
# 20/20 [==============================] - 51s 3s/step - loss: 0.2332 - accuracy: 0.8375 - val_loss: 0.0469 - val_accuracy: 0.9875
# Epoch 2/3
# 20/20 [==============================] - 53s 3s/step - loss: 0.1632 - accuracy: 0.9219 - val_loss: 0.1304 - val_accuracy: 0.9750
# Epoch 3/3
# 20/20 [==============================] - 52s 3s/step - loss: 0.1400 - accuracy: 0.9219 - val_loss: 0.1577 - val_accuracy: 0.9750

# %%
cap = cv.VideoCapture(0)
cap.set(3,640)
cap.set(4,480)
cap.set(10,50)

while True:
    success, img = cap.read()
    break

# %% [markdown]
# cap = cv.VideoCapture(0)
# cap.set(3,640)
# cap.set(4,480)
# cap.set(10,50)
#
# while True:
#     success, img = cap.read()
#     cv.imshow("Video",img)
#     if cv.waitKey(1) & 0xFF ==ord('q'):
#         break

# %%
def prepare(img):
    img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    img = cv.resize(img, (200, 200))
    img = caer.reshape(img, (200, 200), 1)
    return img
predictions = model.predict(prepare(img))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,30))
plt.imshow(img)
plt.show()

# %%
print(people[np.argmax(predictions)])
# Out:
# Vadiraj
